# %%
# !nvidia-smi
# Out:
# Mon Jan 20 09:52:34 2025
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.183.01             Driver Version: 535.183.01   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 3090        Off | 00000000:01:00.0 Off |                  N/A |
# |  0%   40C    P8              34W / 370W |    658MiB / 24576MiB |      9%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.5 🚀 Python-3.12.2 torch-2.4.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3090, 24260MiB)
# Setup complete ✅ (20 CPUs, 62.6 GB RAM, 249.3/273.1 GB disk)

# %%
from ultralytics import YOLO
from IPython.display import Image

# %%
# !pip3 install --upgrade "jax[cuda12]"==0.4.28

# %%
# !yolo task=detect mode=train data=/home/avidmech/Court_side_playground_data/data.yaml model="yolov9e.pt" epochs=30 imgsz=640 batch=16 optimizer="AdamW"
# Out:
# New https://pypi.org/project/ultralytics/8.3.64 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.5 🚀 Python-3.12.2 torch-2.4.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3090, 24260MiB)
# ...

# %% [markdown]
# # ***Training for 4 hours***

# %%
# !yolo task=detect mode=val model="/home/avidmech/runs/detect/train4/weights/best.pt" data=/home/avidmech/Court_side_playground_data/data.yaml
# Out:
# Ultralytics 8.3.5 🚀 Python-3.12.2 torch-2.4.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3090, 24260MiB)
# YOLOv9e summary (fused): 705 layers, 53,204,118 parameters, 0 gradients, 169.5 GFLOPs
# val: Scanning /home/avidmech/Court_side_playground_data/valid/labels.cache... 41
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        414        654      0.986      0.994       0.99      0.972
#       basketball-court        321        322      0.987      0.997      0.988      0.983
#       three point line        321        332      0.986      0.991      0.991       0.96
# Speed: 0.4ms preprocess, 16.8ms inference, 0.0ms loss, 0.7ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %% [markdown]
# # ***Right side video object detection***

# %%
import cv2

from ultralytics import YOLO

# Load the YOLO11 model
model = YOLO("/home/avidmech/runs/detect/train4/weights/best.pt")

# Open the video file
video_path = "/home/avidmech/rr4.mp4"
cap = cv2.VideoCapture(video_path)

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Run YOLO11 tracking on the frame, persisting tracks between frames
        results = model.track(frame, persist=True)

        # Visualize the results on the frame
        annotated_frame = results[0].plot()

        # Display the annotated frame
        cv2.imshow("YOLO11 Tracking", annotated_frame)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()
# Out:
# Streaming output truncated to the last 5000 lines.
# 0: 384x640 (no detections), 11.4ms
# Speed: 1.2ms preprocess, 11.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 11.6ms
# Speed: 1.1ms preprocess, 11.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 11.4ms
# Speed: 1.4ms preprocess, 11.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 11.2ms
# Speed: 1.3ms preprocess, 11.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 11.3ms
# Speed: 1.4ms preprocess, 11.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 11.1ms
# Speed: 1.1ms preprocess, 11.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 12.7ms
# ...

# %% [markdown]
# # ***Left side view object detection***

# %%
import cv2

from ultralytics import YOLO

# Load the YOLO11 model
model = YOLO("/home/avidmech/runs/detect/train4/weights/best.pt")

# Open the video file
video_path = "/home/avidmech/left4.mp4"
cap = cv2.VideoCapture(video_path)

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Run YOLO11 tracking on the frame, persisting tracks between frames
        results = model.track(frame, persist=True)

        # Visualize the results on the frame
        annotated_frame = results[0].plot()

        # Display the annotated frame
        cv2.imshow("YOLO11 Tracking", annotated_frame)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()
